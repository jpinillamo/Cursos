# %% [markdown]
# # Notas curso de Python de platzi de Comprehensions, Funciones y manejo de errores /
#
# Por Nicolas Pinilla

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ## Sets /
# Se pueden modificar
#
#
# No tienen orden en especifico
#
#
# No se pueden tener elementos duplicados

# %%
set_countries = {'col','mex','bol','col'} #No se puede tener elementos repetidos --> lo elimina
print(set_countries)
print(type(set_countries))
# Out:
# {'col', 'mex', 'bol'}
# <class 'set'>

# %%
set_from_string = set('Hooola')
print(set_from_string)
# Out:
# {'a', 'o', 'H', 'l'}

# %%
set_from_tuples = set(['a','v','as','prueba'])
print(set_from_tuples)
# Out:
# {'v', 'as', 'prueba', 'a'}

# %%
numbers =[1,2,3,4,1,2,3,4]
set_numbers=set(numbers)
print(set_numbers)
unique_numbers = list(set_numbers)
print(unique_numbers)
# Out:
# {1, 2, 3, 4}
# [1, 2, 3, 4]

# %% [markdown]
# ## Modificando conjuntos
# * add(): Añade un elemento.
# * update(): Añade cualquier tipo de objeto iterable como: listas, tuplas.
# * discard(): Elimina un elemento y si ya existe no lanza ningún error.
# * remove(): Elimina un elemento y si este no existe lanza el error “keyError”.
# * pop(): Nos devuelve un elemento aleatorio y lo elimina y si el conjunto está vacío lanza el error “key error”.
# * clear(): Elimina todo el contenido del conjunto.

# %%
set_countries = {'col','mex','bol','col'}
size = len(set_countries)
print(size)
print('col' in set_countries)
# Out:
# 3
# True

# %%
#Agregar
set_countries.add('pe')
print(set_countries)
set_countries.add('pe')
print(set_countries)
# Out:
# {'col', 'mex', 'pe', 'bol'}
# {'col', 'mex', 'pe', 'bol'}

# %%
#Actualizar
set_countries.update({'arg','ecu','pe'})
print(set_countries)
# Out:
# {'arg', 'col', 'mex', 'pe', 'ecu', 'bol'}

# %%
#Eliminar
set_countries.remove('col')
print(set_countries)
# Out:
# {'arg', 'mex', 'pe', 'ecu', 'bol'}

# %%
set_countries.discard('arg')
print(set_countries)
# Out:
# {'mex', 'pe', 'ecu', 'bol'}

# %%
#Limpiar todo el conjunto
set_countries.clear()
print(len(set_countries))
# Out:
# 0

# %% [markdown]
# ## Operaciones con conjuntos

# %% [markdown]
# ### Union

# %%
set_a = {'col','mex','bol'}
set_b = {'per','bol'}

# %%
set_c = set_a.union(set_b)
print(set_c)
# Out:
# {'per', 'col', 'mex', 'bol'}

# %%
print(set_a | set_b)
# Out:
# {'per', 'col', 'mex', 'bol'}

# %% [markdown]
# ### Intersección

# %%
set_c = set_a.intersection(set_b)
print(set_c)
print(set_a&set_b)
# Out:
# {'bol'}
# {'bol'}

# %% [markdown]
# ### diferencia

# %%
set_c=set_a.difference(set_b)
print(set_c)
print(set_a-set_b)
# Out:
# {'col', 'mex'}
# {'col', 'mex'}

# %% [markdown]
# ### Diferencia simetrica

# %%
set_c = set_a.symmetric_difference(set_b)
print(set_c)
print(set_a ^ set_b)
# Out:
# {'per', 'mex', 'col'}
# {'per', 'mex', 'col'}

# %% [markdown]
# ## List Comprehension
# Listas con sentencias mas cortas
#
# [element for element in iterable]

# %%
def suma(a = 1, b = 0):
  return a + b

# %%
suma(b=2)
# Out:
# 3

# %%
numbers = []
for i in range (1,11):
    if i%2 ==0:
        numbers.append(i*2)
print(numbers)
# Out:
# [4, 8, 12, 16, 20]

# %%
numbers_v2=[i*2 for i in range(1,11) if i % 2 ==0]
print(numbers_v2)
# Out:
# [4, 8, 12, 16, 20]

# %% [markdown]
# ## Dictionary Comprehension
# {key:value for var in iterable}

# %%
dictionary = {}
for i in range (1,5):
    dictionary[i]= i*2
print(dictionary)
# Out:
# {1: 2, 2: 4, 3: 6, 4: 8}

# %%
dict_v2={i:i*2 for i in range(1,5)}
print(dict_v2)
# Out:
# {1: 2, 2: 4, 3: 6, 4: 8}

# %%
import random
countries = ['col','mex','bol','pe']
population ={}
for country in countries:
    population[country]=random.randint(1,100)

print(population)
# Out:
# {'col': 83, 'mex': 45, 'bol': 74, 'pe': 87}

# %%
population_v2={country:random.randint(1,100) for country in countries}
print(population_v2)
# Out:
# {'col': 29, 'mex': 29, 'bol': 100, 'pe': 5}

# %%
names = [ 'nico','zule','santi']
ages=[12,56,98]

print(list(zip(names,ages)))
new_dict={i:j for (i,j) in zip(names,ages)}
print(new_dict)
# Out:
# [('nico', 12), ('zule', 56), ('santi', 98)]
# {'nico': 12, 'zule': 56, 'santi': 98}

# %% [markdown]
# ## Dictionary Comprehension: condition
# {key:value for var in iterable if condition }

# %%
import random
countries = ['col','mex','bol','pe']

population_v2={country:random.randint(1,100) for country in countries}
print(population_v2)
# Out:
# {'col': 62, 'mex': 69, 'bol': 78, 'pe': 11}

# %%
result = {country:population for (country,population) in population_v2.items() if population >20}
print(result)
# Out:
# {'col': 62, 'mex': 69, 'bol': 78}

# %%
result = {population for (country,population) in population_v2.items() if population >20}
print(result)
# Out:
# {78, 69, 62}

# %%
text = 'Hola, soy Nicolas'
unique = {c:c.upper() for c in text if c in 'aeiou'}
print(unique)
# Out:
# {'o': 'O', 'a': 'A', 'i': 'I'}

# %% [markdown]
# ## Lists vs. Tuples vs. Sets
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Funciones

# %%
def my_print(text):
    print(text * 2)

# %%
my_print('Este es mi texto')
# Out:
# Este es mi textoEste es mi texto

# %%
def suma (a,b):
    c = a + b
    return c

# %%
list(range(1,10))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ## Parámetros por defecto y múltiples returns

# %%
def find_volume(length=1, width=1, depth=1):
    return length*width*depth 

result = find_volume()
print(result)
# Out:
# 1

# %%
def choose_options():   
    options = ('piedra', 'papel', 'tijera') 
    user_option = input('piedra, papel o tijera => ')
    user_option = user_option.lower()

    if not user_option in options:
      print('esa opcion no es valida')
      return None, None

    computer_option = random.choice(options)

    print('User option =>', user_option)
    print('Computer option =>', computer_option)

    return user_option, computer_option

# %%
def check_rules(user_option,computer_option, user_wins ,computer_wins):
    if user_option == computer_option:
        print('Empate!')
    elif user_option == 'piedra':
        if computer_option == 'tijera':
            print('piedra gana a tijera')
            print('user gano!')
            user_wins += 1
        else:
            print('Papel gana a piedra')
            print('computer gano!')
            computer_wins += 1
    elif user_option == 'papel':
        if computer_option == 'piedra':
            print('papel gana a piedra')
            print('user gano')
            user_wins += 1
        else:
            print('tijera gana a papel')
            print('computer gano!')
            computer_wins += 1
    elif user_option == 'tijera':
        if computer_option == 'papel':
            print('tijera gana a papel')
            print('user gano!')
            user_wins += 1
        else:
            print('piedra gana a tijera')
            print('computer gano!')
            computer_wins += 1
    return user_wins, computer_wins

# %%
import random

def run_game():
  computer_wins = 0
  user_wins = 0
  rounds = 1
  
  while True:
      print('*' * 10)
      print('ROUND', rounds)
      print('*' * 10)

      print('computer_wins', computer_wins)
      print('user_wins', user_wins)

      rounds += 1

      user_option, computer_option = choose_options()

      user_wins, computer_wins = check_rules(user_option,computer_option,user_wins, computer_wins)

      if computer_wins == 2:
        print('El ganador es la computadora')
        break

      if user_wins == 2:
        print('El ganador es el usuario')
        break

# %%
run_game()
# Out:
# **********
# ROUND 1
# **********
# computer_wins 0
# user_wins 0
# esa opcion no es valida
# Empate!
# **********
# ROUND 2
# **********
# computer_wins 0
# user_wins 0
# esa opcion no es valida
# Empate!
# **********
# ROUND 3
# **********
# computer_wins 0
# user_wins 0
# esa opcion no es valida
# Empate!
# **********
# ROUND 4
# **********
# computer_wins 0
# user_wins 0
# esa opcion no es valida
# Empate!
# **********
# ROUND 5
# **********
# computer_wins 0
# user_wins 0
# esa opcion no es valida
# Empate!
# **********
# ROUND 6
# **********
# computer_wins 0
# user_wins 0
# esa opcion no es valida
# Empate!
# **********
# ROUND 7
# **********
# computer_wins 0
# user_wins 0
# esa opcion no es valida
# Empate!
# **********
# ROUND 8
# **********
# computer_wins 0
# user_wins 0
# esa opcion no es valida
# Empate!
# **********
# ROUND 9
# **********
# computer_wins 0
# user_wins 0
# esa opcion no es valida
# Empate!
# **********
# ROUND 10
# **********
# computer_wins 0
# ...

# %%
def message_creator(text):
    # Escribe tu solución 👇
    respuestas = {'computadora': 'Con mi computadora puedo programar usando Python',
                  'celular': 'En mi celular puedo aprender usando la app de Platzi',
                  'cable': '¡Hay un cable en mi bota!'}

    return respuestas[text] if text in respuestas else {'Artículo no encontrado'}

text = 'computadora'
response = message_creator(text)
print(response)
# Out:
# Con mi computadora puedo programar usando Python

# %% [markdown]
# ## Funciones lambda

# %%
def increment(x):
    return x+1
result = increment(10)
print(result)
# Out:
# 11

# %%
increment_v2 = lambda x : x+1
result=increment_v2(20)
print(result)
# Out:
# 21

# %%
full_name = lambda name, last_name: f'Full name es {name.title()} {last_name.title()}'
text = full_name('juan','pinilla')
print(text)
# Out:
# Full name es Juan Pinilla

# %% [markdown]
# ## Higher Order Functions

# %%
def increment(x):
    return x+1

increment_v2= lambda x: x+1

def hof(x, func):
    return x + func(x) # --> Aca se ejecuta

hof_v2 = lambda x, func: x+func (x)

result = hof(2, increment) # --> se envia la funcion para que la ejecute la otra
print(result)

result2= hof_v2(2, increment_v2)
print(result2)
# Out:
# 5
# 5

# %% [markdown]
# ## Map

# %%
numbers = [1,2,3,4]
numbers_v2=[]

for i in numbers:
    numbers_v2.append(i*2)

numbers_v3=map(lambda i:i*2,numbers)

print(numbers)
print(numbers_v2)
print(list(numbers_v3))
# Out:
# [1, 2, 3, 4]
# [2, 4, 6, 8]
# [2, 4, 6, 8]

# %%
numbers_1 = [1,2,3,4]
numbers_2=[5,6,7]

result = map(lambda x,y : x+y, numbers_1,numbers_2)

print(list(result))
# Out:
# [6, 8, 10]

# %% [markdown]
# ## Map con diccionarios

# %%
items = [
    {
        'product':'camisa',
        'price': 100
    },
    {
        'product':'pantalones',
        'price': 300
    },
    { 
        'product':'pantalones 2',
        'price': 200
    }
]
prices = list(map(lambda i: i['price'],items))
print(prices)

def add_taxes(item):
    item['taxes']=item['price']* .19
    return item

new_items= list(map(add_taxes,items))
print(new_items)
# Out:
# [100, 300, 200]
# [{'product': 'camisa', 'price': 100, 'taxes': 19.0}, {'product': 'pantalones', 'price': 300, 'taxes': 57.0}, {'product': 'pantalones 2', 'price': 200, 'taxes': 38.0}]

# %% [markdown]
# ## Reto con map

# %%
items = [
    {
        'product':'camisa',
        'price': 100
    },
    {
        'product':'pantalones',
        'price': 300
    },
    { 
        'product':'pantalones 2',
        'price': 200
    }
]

prices = list(map(lambda i: i['price'],items))
print(prices)

def add_taxes(item):
    new_item = item.copy()
    new_item['taxes']=new_item['price']* .19
    return new_item

new_items= list(map(add_taxes,items))
print(new_items)
print(items)
# Out:
# [100, 300, 200]
# [{'product': 'camisa', 'price': 100, 'taxes': 19.0}, {'product': 'pantalones', 'price': 300, 'taxes': 57.0}, {'product': 'pantalones 2', 'price': 200, 'taxes': 38.0}]
# [{'product': 'camisa', 'price': 100}, {'product': 'pantalones', 'price': 300}, {'product': 'pantalones 2', 'price': 200}]

# %% [markdown]
# ## Filter

# %%
numbers = [1,2,3,4,5]
new_numbers = list(filter(lambda x:x %2 ==0, numbers))

print(new_numbers)
# Out:
# [2, 4]

# %%
matches = [
  {
    'home_team': 'Bolivia',
    'away_team': 'Uruguay',
    'home_team_score': 3,
    'away_team_score': 1,
    'home_team_result': 'Win'
  },
  {
    'home_team': 'Brazil',
    'away_team': 'Mexico',
    'home_team_score': 1,
    'away_team_score': 1,
    'home_team_result': 'Draw'
  },
  {
    'home_team': 'Ecuador',
    'away_team': 'Venezuela',
    'home_team_score': 5,
    'away_team_score': 0,
    'home_team_result': 'Win'
  },
]

print(matches)
print(len(matches))

new_list = list(filter(lambda i:i['home_team_result'] == 'Win', matches))
print(new_list)
print(len(new_list))
# Out:
# [{'home_team': 'Bolivia', 'away_team': 'Uruguay', 'home_team_score': 3, 'away_team_score': 1, 'home_team_result': 'Win'}, {'home_team': 'Brazil', 'away_team': 'Mexico', 'home_team_score': 1, 'away_team_score': 1, 'home_team_result': 'Draw'}, {'home_team': 'Ecuador', 'away_team': 'Venezuela', 'home_team_score': 5, 'away_team_score': 0, 'home_team_result': 'Win'}]
# 3
# [{'home_team': 'Bolivia', 'away_team': 'Uruguay', 'home_team_score': 3, 'away_team_score': 1, 'home_team_result': 'Win'}, {'home_team': 'Ecuador', 'away_team': 'Venezuela', 'home_team_score': 5, 'away_team_score': 0, 'home_team_result': 'Win'}]
# 2

# %%
def filter_by_length(words):
   # Escribe tu solución 👇
   return list(filter(lambda i:len(i)>=4,words))

words = ['amor', 'sol', 'piedra', 'día']
response = filter_by_length(words)
print(response)
# Out:
# ['amor', 'piedra']

# %% [markdown]
# ## Reduce

# %%
import functools
numbers = [1,2,3,4]

def accum( counter, item):
    print('counter -->',counter)
    print('item -->',item)
    return counter+item

result = functools.reduce(accum, numbers)
#result = functools.reduce(lambda counter, item:counter+item,numbers)
print (result)
# Out:
# counter --> 1
# item --> 2
# counter --> 3
# item --> 3
# counter --> 6
# item --> 4
# 10

# %%
import functools
numbers = [['Administration', '200'], ['Marketing', '201'], ['Purchasing', '114'], ['Human Resources', '203'], ['Shipping', '121'], ['IT', '103'], ['Public Relations', '204'], ['Sales', '145'], ['Executive', '100'], ['Finance', '108']]
result=0
'''def accum( counter, item):
    print('counter -->',counter)
    print('item -->',item)
    return counter+item

result = functools.reduce(accum, numbers) '''
result = sum(int(r[1]) for r in numbers)

contador = 0
for r in numbers:
    
    aux = int(r[1])
    contador += aux
    print(contador)
    print('cambia')
#print(prueba)

#result = functools.reduce(lambda counter, item:counter+item,numbers)
print (result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[195], line 10
#       3 result=0
#       4 '''def accum( counter, item):
#       5     print('counter -->',counter)
#       6     print('item -->',item)
#       7     return counter+item
#       8
#       9 result = functools.reduce(accum, numbers) '''
# ---> 10 result = sum(int(r[1]) for r in numbers)
#      12 contador = 0
#      13 for r in numbers:
#
# TypeError: <lambda>() missing 1 required positional argument: 'y'

# %% [markdown]
# ## Modulos

# %% [markdown]
# MODULO Un modulo se puede definir que es lo mismo a una biblioteca de código. Es decir es un archivo que contiene un conjunto de funciones que se pueden aplicar.
#
# ### Como crear un Módulo?
# 1. Para crear un módulo debemos escribir el nombre del archivo + la extensión de python que es .py ejemplo name.py
# 2. Escribimos el código que vamos a utilizar en el archivo que acabamos de nombrar.
# 3. Abrimos el archivo con el cual vamos a trabajar y declaramos el modulo que le dimos el nombre por ejemplo con la extensión import, sería de la siguiente manera: import name

# %%
import sys
#print(sys.path)

import re
text = 'Mi numero de telefono es 322 403 6808, el codigo del pais es 57, mi numero de la suerte es 30'
result = re.findall('[0-9]+',text)
print(result)

import time
timestamp = time.time()
local = time.localtime()
result = time.asctime(local)
print(timestamp)
print(result)

import collections
numbers = [1,1,1,2,3,2,32,1,12,32,4,1,4,5]
counter = collections.Counter(numbers)
print(counter)
# Out:
# ['322', '403', '6808', '57', '30']
# 1707405274.7677796
# Thu Feb  8 10:14:34 2024
# Counter({1: 5, 2: 2, 32: 2, 4: 2, 3: 1, 12: 1, 5: 1})

# %%
import miprimermodulo

keys, values = miprimermodulo.get_population()
print(keys,values)
# Out:
# ['col', 'bol'] [300, 400]

# %% [markdown]
# ## Iterables

# %%
my_iter = iter(range(1,11))
print(my_iter)
print(next(my_iter))
print(next(my_iter))
# Out:
# ...
# 1
# 2

# %% [markdown]
# ## Errores

# %%
x = 10
if x < 18:
    raise Exception('No se permiten menores de edad')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 x = 10
#       2 if x < 18:
# ----> 3     raise Exception('No se permiten menores de edad')
#
# Exception: No se permiten menores de edad

# %% [markdown]
# ## Manejo de excepciones

# %%
try:
    print(0/0)
except ZeroDivisionError as error:
    print(error)

    assert 1 != 1, 'Uno no es igual que uno'
except AssertionError as error:
    print(error)

    age =10
    if age <18:
        raise Exception('No se permiten menores de edad')
except Exception as error:
    print(error)

print('hola')
# Out:
# division by zero
# Uno no es igual que uno
# No se permiten menores de edad
# hola

# %% [markdown]
# ## Leer un archivo

# %%
file = open('./text.txt')
#print(file.read())
#print(file.readline())

for line in file:
    print(line)

file.close()
# Out:
# line 1
#
# line 2
#
# line 3
#
# asdf
#
# af{da
#
# {fdaf
#
# afsdf
#
# afsdfaf}}
#
# afsdfaff

# %%
with  open('./text.txt') as file: #--> Con estas instrucciones se cierran solos los archivos
    for line in file:
        print(line)
# Out:
# line 1
#
# line 2
#
# line 3
#
# asdf
#
# af{da
#
# {fdaf
#
# afsdf
#
# afsdfaf}}
#
# afsdfaff

# %% [markdown]
# ## Escribir en un archivo

# %%
with  open('./text.txt','r+') as file: #--> Con estas instrucciones se cierran solos los archivos
    for line in file:
        print(line)
    file.write('\n nuevas cosas en este archivo')
    file.write('\n otra linea')
    file.write('\n otra mas')
# Out:
# Linea 1
#
# Line 2
#
# line 3
#
# line 3
#
# 4
#
# ras
#
# fda
#
# d
#
# a
#
# fdaa
#
# sd
#
# fdaF
#
# Finalnuevas cosas en este archivo

# %% [markdown]
# ## Leer CSV

# %%
import csv

# %%
def read_csv(path):
    with open(path, 'r') as csvfile:
        reader= csv.reader(csvfile,delimiter=',')
        header = next (reader)
        data = []
        for row in reader:
            iterable = zip(header,row)
            country_dict = {key : value for key, value in iterable}
            print(country_dict)
            data.append(country_dict)
        return data
    
if __name__ == '__main__':
    data = read_csv('./world_population.csv')
    print(data)
# Out:
# {'Rank': '36', 'CCA3': 'AFG', 'Country/Territory': 'Afghanistan', 'Capital': 'Kabul', 'Continent': 'Asia', '2022 Population': '41128771', '2020 Population': '38972230', '2015 Population': '33753499', '2010 Population': '28189672', '2000 Population': '19542982', '1990 Population': '10694796', '1980 Population': '12486631', '1970 Population': '10752971', 'Area (kmÂ²)': '652230', 'Density (per kmÂ²)': '63.0587', 'Growth Rate': '1.0257', 'World Population Percentage': '0.52'}
# {'Rank': '138', 'CCA3': 'ALB', 'Country/Territory': 'Albania', 'Capital': 'Tirana', 'Continent': 'Europe', '2022 Population': '2842321', '2020 Population': '2866849', '2015 Population': '2882481', '2010 Population': '2913399', '2000 Population': '3182021', '1990 Population': '3295066', '1980 Population': '2941651', '1970 Population': '2324731', 'Area (kmÂ²)': '28748', 'Density (per kmÂ²)': '98.8702', 'Growth Rate': '0.9957', 'World Population Percentage': '0.04'}
# ...

# %% [markdown]
# ## Gráficas

# %%
#pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
def generate_bar_chart(labels,values):
    fig, ax = plt.subplots()
    ax.bar(labels, values)
    plt.show()

def generate_pie_chart(labels,values):
    fig, ax = plt.subplots()
    ax.pie(values,labels=labels)
    ax.axis('equal')
    plt.show()

if __name__== '__main__':
    labels = ['a','b','c']
    values = [100,200,800]
    generate_bar_chart(labels,values)
    generate_pie_chart(labels,values)

# %% [markdown]
# ## Reto

# %%
data
# Out:
# [{'Rank': '36',
#   'CCA3': 'AFG',
#   'Country/Territory': 'Afghanistan',
#   'Capital': 'Kabul',
#   'Continent': 'Asia',
#   '2022 Population': '41128771',
#   '2020 Population': '38972230',
#   '2015 Population': '33753499',
#   '2010 Population': '28189672',
#   '2000 Population': '19542982',
#   '1990 Population': '10694796',
#   '1980 Population': '12486631',
#   '1970 Population': '10752971',
#   'Area (kmÂ²)': '652230',
#   'Density (per kmÂ²)': '63.0587',
#   'Growth Rate': '1.0257',
#   'World Population Percentage': '0.52'},
#  {'Rank': '138',
#   'CCA3': 'ALB',
#   'Country/Territory': 'Albania',
#   'Capital': 'Tirana',
#   'Continent': 'Europe',
#   '2022 Population': '2842321',
#   '2020 Population': '2866849',
#   '2015 Population': '2882481',
#   '2010 Population': '2913399',
#   '2000 Population': '3182021',
#   '1990 Population': '3295066',
#   '1980 Population': '2941651',
#   '1970 Population': '2324731',
#   'Area (kmÂ²)': '28748',
# ...

# %%
data2 = list(filter(lambda i:i['Country/Territory'] == 'Colombia', data.copy()))
print(data2)
# Out:
# [{'Rank': '28', 'CCA3': 'COL', 'Country/Territory': 'Colombia', 'Capital': 'Bogota', 'Continent': 'South America', '2022 Population': '51874024', '2020 Population': '50930662', '2015 Population': '47119728', '2010 Population': '44816108', '2000 Population': '39215135', '1990 Population': '32601393', '1980 Population': '26176195', '1970 Population': '20905254', 'Area (kmÂ²)': '1141748', 'Density (per kmÂ²)': '45.4339', 'Growth Rate': '1.0069', 'World Population Percentage': '0.65'}]

# %%
def mover_dict(i):
    new_lista = i[0].copy()
    print(new_lista['2020 Population'])
    #print(new_lista)
    
    dict_population = {
        '2022': int(new_lista['2022 Population']),
        '2020': int(new_lista['2020 Population']),
        '2015': int(new_lista['2015 Population']),
        '2010': int(new_lista['2010 Population']),
        '2000': int(new_lista['2000 Population']),
        '1990': int(new_lista['1990 Population'])

    }
    keys = list(dict_population.keys())
    values = list(dict_population.values())
    return keys[::-1],values[::-1]

#keys,values= list(map(mover_dict,data2))
keys,values = mover_dict(data2)
print(keys,values)
# Out:
# 50930662
# ['1990', '2000', '2010', '2015', '2020', '2022'] [32601393, 39215135, 44816108, 47119728, 50930662, 51874024]

# %%
def generate_bar_chart(labels,values):
    fig, ax = plt.subplots()
    ax.bar(labels, values)
    plt.show()

def generate_pie_chart(labels,values):
    fig, ax = plt.subplots()
    ax.pie(values,labels=labels)
    ax.axis('equal')
    plt.show()

if __name__== '__main__':
    generate_bar_chart(keys,values)
    #generate_pie_chart(keys,values)

# %% [markdown]
# ## Reto 2

# %%
data
# Out:
# [{'Rank': '36',
#   'CCA3': 'AFG',
#   'Country/Territory': 'Afghanistan',
#   'Capital': 'Kabul',
#   'Continent': 'Asia',
#   '2022 Population': '41128771',
#   '2020 Population': '38972230',
#   '2015 Population': '33753499',
#   '2010 Population': '28189672',
#   '2000 Population': '19542982',
#   '1990 Population': '10694796',
#   '1980 Population': '12486631',
#   '1970 Population': '10752971',
#   'Area (kmÂ²)': '652230',
#   'Density (per kmÂ²)': '63.0587',
#   'Growth Rate': '1.0257',
#   'World Population Percentage': '0.52'},
#  {'Rank': '138',
#   'CCA3': 'ALB',
#   'Country/Territory': 'Albania',
#   'Capital': 'Tirana',
#   'Continent': 'Europe',
#   '2022 Population': '2842321',
#   '2020 Population': '2866849',
#   '2015 Population': '2882481',
#   '2010 Population': '2913399',
#   '2000 Population': '3182021',
#   '1990 Population': '3295066',
#   '1980 Population': '2941651',
#   '1970 Population': '2324731',
#   'Area (kmÂ²)': '28748',
# ...

# %%
for i in data:
    print(i['Country/Territory'],i['World Population Percentage'])
# Out:
# Afghanistan 0.52
# Albania 0.04
# Algeria 0.56
# American Samoa 0
# Andorra 0
# Angola 0.45
# Anguilla 0
# Antigua and Barbuda 0
# Argentina 0.57
# Armenia 0.03
# Aruba 0
# Australia 0.33
# Austria 0.11
# Azerbaijan 0.13
# Bahamas 0.01
# Bahrain 0.02
# Bangladesh 2.15
# Barbados 0
# Belarus 0.12
# Belgium 0.15
# Belize 0.01
# Benin 0.17
# Bermuda 0
# Bhutan 0.01
# Bolivia 0.15
# Bosnia and Herzegovina 0.04
# Botswana 0.03
# Brazil 2.7
# British Virgin Islands 0
# Brunei 0.01
# Bulgaria 0.09
# Burkina Faso 0.28
# Burundi 0.16
# Cambodia 0.21
# Cameroon 0.35
# Canada 0.48
# Cape Verde 0.01
# Cayman Islands 0
# Central African Republic 0.07
# Chad 0.22
# Chile 0.25
# China 17.88
# Colombia 0.65
# Comoros 0.01
# Cook Islands 0
# Costa Rica 0.06
# Croatia 0.05
# Cuba 0.14
# Curacao 0
# Cyprus 0.02
# Czech Republic 0.13
# Denmark 0.07
# Djibouti 0.01
# Dominica 0
# Dominican Republic 0.14
# DR Congo 1.24
# Ecuador 0.23
# Egypt 1.39
# El Salvador 0.08
# Equatorial Guinea 0.02
# ...

# %%
labels = list(map(lambda i:i['Country/Territory'],data.copy()))
values = list(map(lambda i:float(i['World Population Percentage']),data.copy()))

print(labels)
print(values)
# Out:
# ['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands', 'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia', 'Comoros', 'Cook Islands', 'Costa Rica', 'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czech Republic', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'DR Congo', 'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia', 'Falkland Islands', 'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Guiana', 'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Gr
# ...

# %%
def generate_bar_chart(labels,values):
    fig, ax = plt.subplots()
    ax.bar(labels, values)
    plt.show()

def generate_pie_chart(labels,values):
    fig, ax = plt.subplots()
    ax.pie(values,labels=labels)
    ax.axis('equal')
    plt.show()

if __name__== '__main__':
    #generate_bar_chart(labels,values)
    generate_pie_chart(labels,values)

# %%
names = {'Nicolas', 'Miguel', 'Juan', 'Nicolas'} 
print(names)
# Out:
# {'Nicolas', 'Miguel', 'Juan'}

# %%
sum = lambda 2,3:x+y
print(sum)
# Out:
#   Cell In[128], line 1
#     sum = lambda 2,3:x+y
#                  ^
# SyntaxError: invalid syntax

# %%
d= {}
for e in range(1,6):
     if e <=2:
          d[e]=e-1

print(d)
# Out:
# {1: 0, 2: 1}

# %%
d = {e:e-1 for e in range(1,6) if e<=2}
print(d)
# Out:
# {1: 0, 2: 1}

# %%
set_numbers
# Out:
# {1, 2, 3, 4}

# %%
prueba = {1,2,3,4}

# %%
type(prueba)
# Out:
# set

# %%
a = {1,2}
b = {2,3}
print(a - b)
# Out:
# {1}

# %%
a = {1,2}
b = {2,3}
print(a | b)
# Out:
# {1, 2, 3}

# %%
¿Cuál de las siguientes estructuras de datos es mutable?

a
Tuple

b
List
# Out:
# Object `mutable` not found.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[212], line 4
#       1 get_ipython().run_line_magic('pinfo', 'mutable')
#       3 a
# ----> 4 Tuple
#       6 b
#       7 List
#
# NameError: name 'Tuple' is not defined

# %%
n = []
for i in range (1,6):
    if i <=2:
        n.append(i-1)
n
# Out:
# [0, 1]

# %%
n = [i-1 for i in range(1,6) if i<=2]
n
# Out:
# [0, 1]
