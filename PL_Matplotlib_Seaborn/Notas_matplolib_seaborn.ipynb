# %% [markdown]
# # Pyplot básico

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'ro')
plt.show()

# %%
plt.plot(x,y,'ro-')
plt.show()

# %%
plt.plot(x,y,'ro:')
plt.show()

# %% [markdown]
# # Subplot

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.hist(y)
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.plot(y,x,'b:')
plt.subplot(1,2,2)
plt.pie(y)
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(x,y,'r--')
plt.plot(y,x,'b:')
plt.subplot(2,1,2)
plt.pie(y)
plt.show()

# %%
plt.subplot(2,3,1)
plt.plot(x,y)
plt.subplot(2,3,2)
plt.triplot(x,y)
plt.subplot(2,3,3)
plt.pie(y)
plt.subplot(2,3,4)
plt.scatter(y,x)
plt.subplot(2,3,5)
plt.boxplot(x)
plt.subplot(2,3,6)
plt.stem(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Método orientado a objetos

# %%
fig = plt.figure()
axes = fig.add_axes([0.3,0.1,0.5,0.9])
axes.plot(x,y,'b')
fig.show()
# Out:
# C:\Users\jpini\AppData\Local\Temp\ipykernel_8364\2890348409.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.5,0.9])
axes.plot(x,y,'b')
fig.show()
# Out:
# C:\Users\jpini\AppData\Local\Temp\ipykernel_8364\4018303986.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.9])
axes2 = fig.add_axes([0.2,0.55,0.4,0.3])
axes.plot(x,y,'b')
axes2.plot(y,x,'r')
axes2.set_facecolor('gray')
fig.show()
# Out:
# C:\Users\jpini\AppData\Local\Temp\ipykernel_8364\636884606.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# # SubplotS

# %%
x = np.linspace(0,10,22)
y = np.sin(x)

# %%
fig, axes = plt.subplots()
axes.plot(x,y,'b')

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y,'b')
axes[1].plot(y,x,'r')

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1,ncols=2)
ax1.plot(x,y,'b')
ax2.plot(y,x,'r')

# %%
'''fig, ax1 = plt.subplots(1,1)
ax1.fill_between()'''
# Out:
# 'fig, ax1 = plt.subplots(1,1)\nax1.fill_between()'

# %%
fig, axes = plt.subplots(2,4)
axes[0,0].plot(x,np.sin(x),'b')
axes[0,1].plot(x,np.cos(x),'y')
axes[0,2].plot(x,np.tan(x),'r')
axes[0,3].plot(x,1/np.tan(x),'g')
axes[1,0].plot(x,1/np.cos(x),'y')
axes[1,1].plot(x,1/np.sin(x),'b:')
axes[1,2].plot(x,y,'b:')
axes[1,3].fill_between(x,y)
fig.tight_layout()
# Out:
# C:\Users\jpini\AppData\Local\Temp\ipykernel_8364\1073027219.py:5: RuntimeWarning: divide by zero encountered in divide
#   axes[0,3].plot(x,1/np.tan(x),'g')
# C:\Users\jpini\AppData\Local\Temp\ipykernel_8364\1073027219.py:7: RuntimeWarning: divide by zero encountered in divide
#   axes[1,1].plot(x,1/np.sin(x),'b:')

# %% [markdown]
# # Leyendas, titulos, etc.

# %%
fig, axes = plt.subplots(1,2,figsize=(10,5))
axes[0].plot(x,y,label='Sin(x)')
axes[0].set_title('Relación X con Y')
axes[0].set_xlabel('Eje X')
axes[0].set_ylabel('Eje Y')
axes[0].legend(loc='lower right',bbox_to_anchor=(1.2,1))
axes[1].plot(y,x)
axes[1].set_title('Relación Y con X')
axes[1].set_xlabel('Eje Y')
axes[1].set_ylabel('Eje X')
# Out:
# Text(0, 0.5, 'Eje X')

# %% [markdown]
# # Colores y estilos

# %%
x = np.linspace(0,5,11)

# %%
print(plt.style.available) #Listados que se pueden utilizas
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
#plt.style.use('bmh') # Se pueden escoger
#plt.style.use('dark_background')

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x,x+1,'r--')
ax.plot(x,x+2,'b-')
ax.plot(x,x+3,'y.')
ax.plot(x,x+4,'go:')

# %% [markdown]
# # Bar plot

# %%
import seaborn as sns

# %%
country = ['India','Japan','Mexico','Colombia','Germany']
population = [1000,800,900,1000,300]
#plt.style.use('Solarize_Light2')
#plt.style.use('bmh')

# %%
country = ['India', 'Japan', 'Mexico', 'Colombia', 'Germany']
population = [1000, 800, 900, 1000, 300]

country_population = dict(sorted({country[k]:population[k] for k in range(len(country))}.items(), key = lambda i:i[1], reverse=True))
print(country_population)

#Crea un diccionario iterando listas
#{country[k]:population[k] for k in range(len(country))}

#llama a los items del diccionario
#{country[k]:population[k] for k in range(len(country))}.items()

#Utiliza la función sorted para ordenarlos - sorted en este caso debe recibir por que lo vas a ordenar y como va  a quedar el orden final
#sorted({country[k]:population[k] for k in range(len(country))}.items(), key = lambda i:i[1])

#Ordenar por values, por la lista de population
#key = lambda i:i[1]

#Que quede primero el mas grande
#reverse=True

#Volverlo diccionario
#dict(todo)
# Out:
# {'India': 1000, 'Colombia': 1000, 'Mexico': 900, 'Japan': 800, 'Germany': 300}

# %%
plt.bar(country_population.keys(),country_population.values(), width= 0.5,color=sns.color_palette("tab10"))
plt.xticks(np.arange(5),country_population.keys(),rotation=45)
plt.title('Población por pais')
plt.xlabel('Pais')
plt.ylabel('Población en 100 millones de personas')
plt.xlim(-1,5)
plt.ylim(0,1050)
plt.show()

# %%
plt.barh([i for i in country_population.keys()][::-1],[i for i in country_population.values()][::-1])
plt.title('Población por pais')
plt.xlabel('Pais')
plt.ylabel('Población en 100 millones de personas')
plt.ylim(-1,5)
plt.xlim(0,1050)
plt.show()

# %% [markdown]
# # Crear otro tipo de gráficas

# %%
data = np.random.randint(1,50,100)
data
# Out:
# array([49, 11, 14, 29, 16,  1, 39,  9, 40, 42, 16,  5, 33, 37, 39, 12, 11,
#         8, 30, 11,  7,  9, 29, 26,  9, 33, 43, 40, 10, 38, 12, 49, 44,  1,
#        45,  3, 35, 38, 46, 47, 27, 17, 48, 12, 21, 14, 27, 45,  1, 20,  1,
#        21, 38, 35, 12, 27, 40, 45, 37,  7, 31, 28, 27,  9,  9,  4, 22, 13,
#        49, 47, 34,  1, 30, 18, 49, 21, 16,  6, 32, 25, 10, 19, 49, 16, 26,
#        26, 42, 45,  1,  1, 25, 26, 43, 37, 27,  5,  1, 48, 13,  4])

# %% [markdown]
# ## Histograma

# %%
plt.hist(data, bins = 10, histtype='step')
# Out:
# (array([13., 11., 11.,  8.,  4., 14.,  7., 10.,  8., 14.]),
#  array([ 1. ,  5.8, 10.6, 15.4, 20.2, 25. , 29.8, 34.6, 39.4, 44.2, 49. ]),
#  [<matplotlib.patches.Polygon at 0x222d0e544d0>])

# %% [markdown]
# ## Boxplot

# %%
data = np.append(data,100)
plt.boxplot(data, patch_artist=True,notch=True)
plt.show()

# %% [markdown]
# ## Scatter

# %%
n = 50
x=np.random.rand(n)
y = np.random.rand(n)
area = (30 * np.random.rand(n)) **2
colors = np.random.rand(n)

# %%
plt.scatter(x,y,s=area,c=colors,marker='p',alpha=0.7)
plt.show()

# %% [markdown]
# # Seaborn

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Set

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x=['A','B','C'],y=[1,3,2])
plt.show()

# %%
sns.set(style="dark",palette="muted",font='Verdana',font_scale=1)
sns.barplot(x=['A','B','C'],y=[1,3,2])
plt.show()

# %% [markdown]
# ## Parametros mas usados de seaborn

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(data=tips, x='total_bill')
plt.show()

# %%
sns.displot(data=tips, x='total_bill',y='tip')
plt.show()

# %%
sns.displot(data=tips, x='total_bill',y='tip',hue='sex')
plt.show()

# %%
sns.displot(data=tips, x='total_bill',hue='sex',kind='kde')
plt.show()

# %%
sns.displot(data=tips, x='total_bill',hue='sex',kind='kde',palette='dark',alpha=.25)
plt.show()

# %% [markdown]
# ## Distribuciones

# %%
sns.histplot(data=tips, x='tip',bins=15,cumulative=False,hue='sex',stat='count',multiple='dodge')
plt.show()

# %%
sns.kdeplot(data=tips,x='tip',hue='sex',cumulative=True)
plt.show()

# %%
sns.kdeplot(data=tips,x='tip',hue='sex',cumulative=False,fill=True)
plt.show()

# %%
sns.ecdfplot(data=tips,x='tip',hue='sex')
# Out:
# <Axes: xlabel='tip', ylabel='Proportion'>

# %% [markdown]
# # Categóricos

# %%
sns.countplot(data=tips,x='day',hue='sex')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.stripplot(data=tips,x='day',y='total_bill',hue='sex',dodge=True)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.swarmplot(data=tips,x='day',y='total_bill',hue='sex',dodge=True)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.boxplot(data=tips,x='day',y='total_bill',hue='sex',dodge=True)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.swarmplot(data=tips,x='day',y='total_bill',hue='sex',dodge=True,color="1",marker="<")
sns.boxplot(data=tips,x='day',y='total_bill',hue='sex',dodge=True)
plt.show()
# Out:
# C:\Users\jpini\AppData\Local\Temp\ipykernel_24376\2912092047.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:1'` for the same effect.
#
#   sns.swarmplot(data=tips,x='day',y='total_bill',hue='sex',dodge=True,color="1",marker="<")

# %%
sns.catplot(data=tips,x='day',y='total_bill',hue='sex',dodge=True)
plt.show()

# %% [markdown]
# # Relation

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='day',style='time',size='size')
plt.legend(loc='center',bbox_to_anchor=(1.12,0.5))
plt.show()

# %%
marker = {'Lunch':'D','Dinner':'s'}
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='day',style='time',size='size',markers=marker)
plt.legend(loc='center',bbox_to_anchor=(1.12,0.5))
plt.show()

# %%
sns.lineplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',hue='sex',marginal_ticks=True)
plt.show()

# %%
sns.pairplot(data=tips,hue='sex',palette='coolwarm',corner=True)
plt.show()
