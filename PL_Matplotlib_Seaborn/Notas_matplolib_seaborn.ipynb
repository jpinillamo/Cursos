# %% [markdown]
# # Pyplot básico

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'ro')
plt.show()

# %%
plt.plot(x,y,'ro-')
plt.show()

# %%
plt.plot(x,y,'ro:')
plt.show()

# %% [markdown]
# # Subplot

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.hist(y)
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.plot(y,x,'b:')
plt.subplot(1,2,2)
plt.pie(y)
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(x,y,'r--')
plt.plot(y,x,'b:')
plt.subplot(2,1,2)
plt.pie(y)
plt.show()

# %%
plt.subplot(2,3,1)
plt.plot(x,y)
plt.subplot(2,3,2)
plt.triplot(x,y)
plt.subplot(2,3,3)
plt.pie(y)
plt.subplot(2,3,4)
plt.scatter(y,x)
plt.subplot(2,3,5)
plt.boxplot(x)
plt.subplot(2,3,6)
plt.stem(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Método orientado a objetos

# %%
fig = plt.figure()
axes = fig.add_axes([0.3,0.1,0.5,0.9])
axes.plot(x,y,'b')
fig.show()
# Out:
# C:\Users\jpini\AppData\Local\Temp\ipykernel_28200\2890348409.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.5,0.9])
axes.plot(x,y,'b')
fig.show()
# Out:
# C:\Users\jpini\AppData\Local\Temp\ipykernel_28200\4018303986.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.9])
axes2 = fig.add_axes([0.2,0.55,0.4,0.3])
axes.plot(x,y,'b')
axes2.plot(y,x,'r')
axes2.set_facecolor('gray')
fig.show()
# Out:
# C:\Users\jpini\AppData\Local\Temp\ipykernel_28200\636884606.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# # SubplotS

# %%
x = np.linspace(0,10,22)
y = np.sin(x)

# %%
fig, axes = plt.subplots()
axes.plot(x,y,'b')

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y,'b')
axes[1].plot(y,x,'r')

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1,ncols=2)
ax1.plot(x,y,'b')
ax2.plot(y,x,'r')

# %%
fig, ax1 = plt.subplots(1,1)
ax1.fill_between()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 fig, ax1 = plt.subplots(1,1)
# ----> 2 ax1.fill_between()
#
# File c:\Users\jpini\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# TypeError: Axes.fill_between() missing 2 required positional arguments: 'x' and 'y1'

# %%
fig, axes = plt.subplots(2,4)
axes[0,0].plot(x,np.sin(x),'b')
axes[0,1].plot(x,np.cos(x),'y')
axes[0,2].plot(x,np.tan(x),'r')
axes[0,3].plot(x,1/np.tan(x),'g')
axes[1,0].plot(x,1/np.cos(x),'y')
axes[1,1].plot(x,1/np.sin(x),'b:')
axes[1,2].plot(x,y,'b:')
axes[1,3].fill_between(x,y)
fig.tight_layout()
# Out:
# C:\Users\jpini\AppData\Local\Temp\ipykernel_22548\1073027219.py:5: RuntimeWarning: divide by zero encountered in divide
#   axes[0,3].plot(x,1/np.tan(x),'g')
# C:\Users\jpini\AppData\Local\Temp\ipykernel_22548\1073027219.py:7: RuntimeWarning: divide by zero encountered in divide
#   axes[1,1].plot(x,1/np.sin(x),'b:')

# %% [markdown]
# # Leyendas, titulos, etc.

# %%
fig, axes = plt.subplots(1,2,figsize=(10,5))
axes[0].plot(x,y,label='Sin(x)')
axes[0].set_title('Relación X con Y')
axes[0].set_xlabel('Eje X')
axes[0].set_ylabel('Eje Y')
axes[0].legend(loc='lower right',bbox_to_anchor=(1.2,1))
axes[1].plot(y,x)
axes[1].set_title('Relación Y con X')
axes[1].set_xlabel('Eje Y')
axes[1].set_ylabel('Eje X')
# Out:
# Text(0, 0.5, 'Eje X')

# %% [markdown]
# # Colores y estilos

# %%
x = np.linspace(0,5,11)

# %%
print(plt.style.available) #Listados que se pueden utilizas
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('bmh') # Se pueden escoger
plt.style.use('dark_background')

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x,x+1,'r--')
ax.plot(x,x+2,'b-')
ax.plot(x,x+3,'y.')
ax.plot(x,x+4,'go:')

# %% [markdown]
# # Bar plot

# %%
import seaborn as sns

# %%
country = ['India','Japan','Mexico','Colombia','Germany']
population = [1000,800,900,1000,300]
#plt.style.use('Solarize_Light2')
#plt.style.use('bmh')

# %%
# Out:
# {'India': 1000, 'Japan': 800, 'Mexico': 900, 'Colombia': 1000, 'Germany': 300}

# %%
country = ['India', 'Japan', 'Mexico', 'Colombia', 'Germany']
population = [1000, 800, 900, 1000, 300]

country_population = dict(sorted({country[k]:population[k] for k in range(len(country))}.items(), key = lambda i:i[1], reverse=True))
print(country_population)

#Crea un diccionario iterando listas
#{country[k]:population[k] for k in range(len(country))}

#llama a los items del diccionario
#{country[k]:population[k] for k in range(len(country))}.items()

#Utiliza la función sorted para ordenarlos - sorted en este caso debe recibir por que lo vas a ordenar y como va  a quedar el orden final
#sorted({country[k]:population[k] for k in range(len(country))}.items(), key = lambda i:i[1])

#Ordenar por values, por la lista de population
#key = lambda i:i[1]

#Que quede primero el mas grande
#reverse=True

#Volverlo diccionario
#dict(todo)
# Out:
# {'India': 1000, 'Colombia': 1000, 'Mexico': 900, 'Japan': 800, 'Germany': 300}

# %%
plt.bar(country_population.keys(),country_population.values(), width= 0.5,color=sns.color_palette("tab10"))
plt.xticks(np.arange(5),country_population.keys(),rotation=45)
plt.title('Población por pais')
plt.xlabel('Pais')
plt.ylabel('Población en 100 millones de personas')
plt.xlim(-1,5)
plt.ylim(0,1050)
plt.show()

# %%
plt.barh([i for i in country_population.keys()][::-1],[i for i in country_population.values()][::-1])
plt.title('Población por pais')
plt.xlabel('Pais')
plt.ylabel('Población en 100 millones de personas')
plt.ylim(-1,5)
plt.xlim(0,1050)
plt.show()

# %% [markdown]
# # Crear otro tipo de gráficas

# %%
data = np.random.randint(1,50,100)
data
# Out:
# array([ 4, 49,  9, 29,  8, 46, 25, 15, 24, 16, 33, 49, 28,  2, 11, 42,  2,
#        14, 48, 35, 33,  7, 10, 44, 29, 29, 11, 48, 16, 30, 48, 19, 39, 23,
#        44, 24,  5, 18,  6, 26, 15,  6, 17,  5, 12, 26,  4, 31, 41, 10, 42,
#        19, 23,  5, 26, 24, 19, 45, 45, 24, 29, 33, 27, 23, 47, 33, 37, 48,
#        14, 37, 31, 37,  7, 48, 18, 34, 48,  6, 42, 44, 45, 20, 10, 28, 29,
#        42,  2, 41, 38,  6, 14,  9, 37, 48, 46,  6, 44, 39, 34, 45])

# %% [markdown]
# ## Histograma

# %%
plt.hist(data, bins = 10, histtype='step')
# Out:
# (array([13., 10.,  8.,  7.,  8., 12.,  8.,  8., 10., 16.]),
#  array([ 2. ,  6.7, 11.4, 16.1, 20.8, 25.5, 30.2, 34.9, 39.6, 44.3, 49. ]),
#  [<matplotlib.patches.Polygon at 0x28bf1b91ad0>])

# %% [markdown]
# ## Boxplot

# %%
data = np.append(data,100)
plt.boxplot(data, patch_artist=True,notch=True)
plt.show()

# %% [markdown]
# ## Scatter

# %%
n = 50
x=np.random.rand(n)
y = np.random.rand(n)
area = (30 * np.random.rand(n)) **2
colors = np.random.rand(n)

# %%
plt.scatter(x,y,s=area,c=colors,alpha=0.7)
plt.show()
