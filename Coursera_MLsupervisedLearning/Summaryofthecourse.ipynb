# %% [markdown]
# # Summary of week 1
# jnpm

# %% [markdown]
# Let's talk about prediction tasks in supervised learning. Prediction task can be either classification or regression depending on the labels datatype. When the label is categorical variable, which means a zero or one, or 1,2,3 or A, B, C. These are called categorical variables, and in that case, it becomes classification. If the categories are binary, it is called the binary class classification. If it's a multi categories call them multi-class classification. Binary multiclass. The other hand, if the label variable is a real valued variable, so something like 0.1, 0.999, something like that, or 3.4. Real value variables to predict those labels given the data is called a regression problem.

# %% [markdown]
# Definicion de modelos
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Books of the course
# * https://hastie.su.domains/ElemStatLearn/printings/ESLII_print12.pdf

# %% [markdown]
# ## Simple Linear Regression
#
# ISLR 3.1: Simple Linear Regression
#
# * Supervised learning model
# * Predictive task - real valued numbers
# * Parametric model
# * No hyperparameters
# * Features have linear relationship to the target variable

# %% [markdown]
# ## Linear Regressión Model Optimization
#
# ISLR 3.1.1: Estimating the Coefficients
#
# ![image.png](attachment:image.png)

# %% [markdown]
# * MSE
# * MAE
# * MAPE
# * RMSE
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Important thing to remember is that the slope is proportional to the covariance of the variable X and Y and then inversely proportional to the variance of X. And similarly, intercept has this relation. And if you look at carefully, this suggests that actually the regression line passes through the center which is mean of X and comma mean of Y.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ISLR 3.1.2: Assessing the Accuracy of the Coefficient Estimates
#
# It means
# that on the basis of one particular set of observations y1,...,yn, µˆ might
# overestimate µ, and on the basis of another set of observations, µˆ might
# underestimate µ. But if we could average a huge number of estimates of
# µ obtained from a huge number of sets of observations, then this average
# would exactly equal µ. Hence, an unbiased estimator does not systematically
# over- or under-estimate the true parameter.

# %% [markdown]
# ISLR 3.1.3: Assessing the Accuracy of the Model

# %% [markdown]
# Coefficient Significance and Test Error

# %% [markdown]
# # Summary of week 2

# %% [markdown]
# ![image.png](attachment:image.png)
